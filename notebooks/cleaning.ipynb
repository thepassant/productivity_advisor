# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw_data.csv")
df.columns = df.columns.str.lower().str.replace(' ', '_ ')
df.pop('framework_id')
# Out:
# 0       4
# 1      38
# 2      46
# 3       8
# 4      29
#        ..
# 245    37
# 246    46
# 247    20
# 248    38
# 249    17
# Name: framework_id, Length: 250, dtype: int64

# %%
df = df.drop_duplicates(subset='task')

# %%
df.to_csv("../data/cleaned_data.csv", index=False)

# %%
df = pd.read_csv('../data/cleaned_data.csv')

print(df.columns)
# Out:
# Index(['id', 'task', 'category', 'difficulty', 'duration_estimate',
#        'framework_name', 'reasoning', 'instructions', 'tags'],
#       dtype='str')
